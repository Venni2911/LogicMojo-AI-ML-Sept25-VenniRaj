# %% [markdown]
# <a href="https://colab.research.google.com/github/Venni2911/LogicMojo-AI-ML-Sept25-VenniRaj/blob/main/Venni_Practise__19_11__Probability_theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Probability = relevant events that we are looking for / all possible outcomes Probability score between 0 and 1
sample set/space = set of all possible outcomes of random experiment
random exp = any process or action for which the outcome cannot be predicted with certainty. ex rolling a dice Event - subset of sample space . random exp == rolling a dice.
event - getting even number/ odd number
Events - Simple Event (single outcome) , Compound Event (multiple Outcomes) ,
Mutually exclusive event (events cannot accur simultaneously - when you flip a coin you cannot get head and tail together,
Exhautive Event - when flipping a coin - you get event of getting tail and you get event of getting head - only these two possibilities - nothing else - so this kind of eventa are exhaustive event - it covers all possible outcomes of experiment .
another example - i have sample space of {0,1,2,3,4,5} . then i have an event of getting odd or even . this is not exhaustive in nature because 0 is not even nor odd.

# %%
Rule of Multiplication - both events are going to happen - both events - AND keyword
P(A)∩P(B) = P(A∩B) = P(A) * P(B) - this is only true for independent events
Dependent event - second event depends on outcome of first event = P(A intersection B)= P(A) * P(B/A)

Rule of Addition - either event can happen - OR keyword  -> P(AUB) = P(A) + P(B) - P(A∩B)

# %%
Conditional Probability - prob of one event given other event already occured
P(A|B)= P(A intersection B)/P(B)
A card is drawn from a standard deck of 52 cards. Find the probability that it is
a) a king or a heart
b) a red card or a face card

P(King or Heart) = P(King) + P(Heart) - P(King intersection Heart)
P(red card or face card) = P(red card) + P(face card) - P(red card intersection face card

# %%
A card is drawn from a deck. Find the probability that it is
a) a heart, given that it is red
b) a king, given that it is a face card

P(H|R) = P(H intersection R)/P(R)
total card heart and red = 13 , total red cards = 26
13/52 / 26/52 = 13/26 = 1/2


P(K|F) = P(K intersection F)/P(F)

# %%
Two cards are drawn without replacement. Find the probability that
a) the second card is a heart, given the first card is a heart
b) the second card is a king, given the first card is a king
c) draw 2 cards witout replacement, find prob of both being hearts

dependent in nature (without replacing)
a) 12/51
b) 3/51
c)13/52 * 12/51 = 156/3176 - dependent in nature (without replacing)
13/52 * 13/52 - independent in nature

# %%
Bayes Theorm
P(A|B) = P(B|A) * P(A)/P(B)



A factory has two machines, M1 and M2.

M1 produces 60% of items, M2 produces 40%.

Defective rates: 3% for M1, 5% for M2.
If an item is found defective, what is the probability it was produced by M1?
P(M1/+defect) = P(+defect|M1) * P(M1)/P(+defect)
P(+defect|M1) = 0.03 = 3%
P(M1) = 0.6 = 60%
P(+defect) = P(+defect|M1) * P(M1) + P(+defect|M2) * P(M2)

=0.03 * 0.6 / (0.03 * 0.6 + 0.05 * 0.4)

# %%
A certain disease affects 1% of the population. A test has:

Sensitivity (true positive rate) = 95%

Specificity (true negative rate) = 90%
If a person tests positive, what is the probability they actually have the disease?

P(D/+ve) = P(+ve/D) * P(D)/P(+Ve)
P(+ve/D) = 95% = 0.95
P(D) = !% got the disease = 0.01%
P(+ve) = P(+ve/D) * P(D) + P(+ve/ND) * P(ND) = 0.95*0.01 + 0.10 * 0.99 (1-0.01)

# %%
There are three boxes:

Box A: 2 gold, 1 silver

Box B: 1 gold, 2 silver

Box C: 3 silver
A box is chosen at random and a coin (or ball) is drawn. If it is gold, what is the probability it came from Box A?

i.e given gold, then whats the prob of it comes from A
P(A/G) = P(G/A) * P(A)/P(G)
P(G/A) = 2/3
P(A) = 1/3
P(G) = P(G/A) * P(A) + P(G/B) * P(B) + P(G/C) * P(C)
P(G) = 2/3 * 1/3 + 1/3 * 1/3 + 0 * 1/3 = 2/9+1/9 = 3/9
P(A/G) = 2/3 * 1/3 / 3/9 = 2/3

# %% [markdown]
# Random variable = outcome of an experiment
# discreate and continuous
#
# Mean = avg of discreate statistics
# Expected mean = Avg of predicted or inferrential statistics
#
# Variance - the spread of random variable from mean
# Covariance = how two variables change together
