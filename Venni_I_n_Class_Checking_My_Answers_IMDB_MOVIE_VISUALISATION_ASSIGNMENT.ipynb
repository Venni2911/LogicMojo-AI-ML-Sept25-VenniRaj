# %% [markdown]
# <a href="https://colab.research.google.com/github/Venni2911/LogicMojo-AI-ML-Sept25-VenniRaj/blob/main/Venni_I_n_Class_Checking_My_Answers_IMDB_MOVIE_VISUALISATION_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the csv file using 'read_csv'. Please write your dataset location here.
Vdf = pd.read_csv('/content/drive/MyDrive/Venni Movie Assignment/Movie+Assignment+Data.csv')

Vdf
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
Vdf. head()
Vdf.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
# Check the number of rows and columns in the dataframe
Vdf.shape
# Out:
# (100, 62)

# %%
Vdf.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
# Check the column-wise info of the dataframe
Vdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns
Vdf.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# Subtask 2.1: Reduce those Digits!
# These numbers in the budget and gross are too big, compromising its readability. Let's convert the unit of the budget and gross columns from $ to million $ first.

# %%
Vdf['budget']
# Out:
# 0      30000000
# 1     150000000
# 2      12000000
# 3      47000000
# 4       9000000
#         ...
# 95      3300000
# 96      3000000
# 97    245000000
# 98    150000000
# 99      5000000
# Name: budget, Length: 100, dtype: int64

# %%
Mdf = pd.read_csv('/content/drive/MyDrive/Venni Movie Assignment/Movie+Assignment+Data.csv')
Mdf['budget']
Mdf['budget'] = Mdf['budget'].apply(lambda x: x/1000000)
Mdf['budget'].head(10)
# Out:
# 0     30.0
# 1    150.0
# 2     12.0
# 3     47.0
# 4      9.0
# 5     12.0
# 6    165.0
# 7    260.0
# 8    250.0
# 9    250.0
# Name: budget, dtype: float64

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
Vdf['budget'] = Vdf['budget'].apply(lambda x: x/1000000)
Vdf['budget']
# Out:
# 0      30.0
# 1     150.0
# 2      12.0
# 3      47.0
# 4       9.0
#       ...
# 95      3.3
# 96      3.0
# 97    245.0
# 98    150.0
# 99      5.0
# Name: budget, Length: 100, dtype: float64

# %%
Vdf['Gross'] = Vdf['Gross'].apply(lambda x: x/1000000)

# %%
Vdf['Gross']
# Out:
# 0     151101803
# 1     341268248
# 2      51738905
# 3     100546139
# 4      47695371
#         ...
# 95     13092000
# 96      8114507
# 97    936662225
# 98    296347721
# 99       223838
# Name: Gross, Length: 100, dtype: int64

# %%
Vdf.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column
Vdf['profit'] = Vdf['Gross'] - Vdf['budget']
Vdf[['Gross','budget','profit']]
# Out:
#          Gross  budget      profit
# 0   151.101803    30.0  121.101803
# 1   341.268248   150.0  191.268248
# 2    51.738905    12.0   39.738905
# 3   100.546139    47.0   53.546139
# 4    47.695371     9.0   38.695371
# ..         ...     ...         ...
# 95   13.092000     3.3    9.792000
# 96    8.114507     3.0    5.114507
# 97  936.662225   245.0  691.662225
# 98  296.347721   150.0  146.347721
# 99    0.223838     5.0   -4.776162
#
# [100 rows x 3 columns]

# %%
Vdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    float64
#  3   Gross                   100 non-null    float64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'

Vdf.sort_values('profit',ascending=False)
Vdf['profit']


Vdf.sort_values('profit',ascending=False,inplace=True)
Vdf['profit']
# Out:
# 97    691.662225
# 11    403.279547
# 47    305.024263
# 32    294.645577
# 12    214.984497
#          ...
# 46    -28.505730
# 7     -59.192738
# 17    -77.810499
# 39    -79.860848
# 22    -96.179906
# Name: profit, Length: 100, dtype: float64

# %%
Vdf.head()
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# 11  623.279547    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 47  363.024263      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 32  424.645577  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 12  414.984497          Tom Hanks  John Ratzenberger            Don Rickles
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %% [markdown]
# # Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)

# %%
top10 = Vdf.head(10)
top10
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
top10.head()
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# 11  623.279547    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 47  363.024263      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 32  424.645577  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 12  414.984497          Tom Hanks  John Ratzenberger            Don Rickles
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
top10.iloc[0:11]
top10.iloc[:10]
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
top10.iloc[0:11][['Title']]
# Out:
#                                          Title
# 97  Star Wars: Episode VII - The Force Awakens
# 11                                The Avengers
# 47                                    Deadpool
# 32             The Hunger Games: Catching Fire
# 12                                 Toy Story 3
# 8                        The Dark Knight Rises
# 45                              The Lego Movie
# 1                                     Zootopia
# 41                               Despicable Me
# 18                                  Inside Out

# %%
top10.iloc[0:11][['Title','budget','Gross','profit']]
# Out:
#                                          Title  budget       Gross      profit
# 97  Star Wars: Episode VII - The Force Awakens   245.0  936.662225  691.662225
# 11                                The Avengers   220.0  623.279547  403.279547
# 47                                    Deadpool    58.0  363.024263  305.024263
# 32             The Hunger Games: Catching Fire   130.0  424.645577  294.645577
# 12                                 Toy Story 3   200.0  414.984497  214.984497
# 8                        The Dark Knight Rises   250.0  448.130642  198.130642
# 45                              The Lego Movie    60.0  257.756197  197.756197
# 1                                     Zootopia   150.0  341.268248  191.268248
# 41                               Despicable Me    69.0  251.501645  182.501645
# 18                                  Inside Out   175.0  356.454367  181.454367

# %%
top10_Indexing = Vdf.sort_values('profit',ascending=False).head(10).reset_index(drop=True)
top10_Indexing
# Out:
#                                         Title  title_year  budget       Gross  \
# 0  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662225
# 1                                The Avengers        2012   220.0  623.279547
# 2                                    Deadpool        2016    58.0  363.024263
# 3             The Hunger Games: Catching Fire        2013   130.0  424.645577
# 4                                 Toy Story 3        2010   200.0  414.984497
# 5                       The Dark Knight Rises        2012   250.0  448.130642
# 6                              The Lego Movie        2014    60.0  257.756197
# 7                                    Zootopia        2016   150.0  341.268248
# 8                               Despicable Me        2010    69.0  251.501645
# 9                                  Inside Out        2015   175.0  356.454367
#
#         actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
top10_Indexing.loc[0:11,['Title']]
# Out:
#                                         Title
# 0  Star Wars: Episode VII - The Force Awakens
# 1                                The Avengers
# 2                                    Deadpool
# 3             The Hunger Games: Catching Fire
# 4                                 Toy Story 3
# 5                       The Dark Knight Rises
# 6                              The Lego Movie
# 7                                    Zootopia
# 8                               Despicable Me
# 9                                  Inside Out

# %%
#Plot profit vs budget
Vdf.plot(kind='scatter',x='budget',y='profit')
# Out:
# <Axes: xlabel='budget', ylabel='profit'>

# %%
top10[['profit','budget']].corr()
# Out:
#           profit    budget
# profit  1.000000  0.429765
# budget  0.429765  1.000000

# %%
Vdf.plot(x='title_year', y='profit', kind='bar', figsize=(8,5))
# Out:
# <Axes: xlabel='title_year'>

# %%
top10.plot(x='title_year', y='profit', kind='bar', figsize=(8,5))
# Out:
# <Axes: xlabel='title_year'>

# %%
Vdf['profit'].plot(kind='hist',bins=10,color='red',edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
Vdf[['budget','profit']].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.lmplot(x='budget',y='profit',data=Vdf,fit_reg=False)

# %%
sns.jointplot(x='budget',y='profit',data=Vdf)

# %%
Vdf_negativeprofit = Vdf[Vdf['profit']<0]
Vdf_negativeprofit
# Out:
#                           Title  title_year     budget      Gross  \
# 99      Tucker and Dale vs Evil        2010    5000000     223838
# 89                        Amour        2012    8900000     225377
# 56                         Rush        2013   38000000   26903709
# 66                      Warrior        2011   25000000   13651662
# 82                      Flipped        2010   14000000    1752214
# 28           X-Men: First Class        2011  160000000  146405371
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
# 7                       Tangled        2010  260000000  200807262
# 17             Edge of Tomorrow        2014  178000000  100189501
# 39            The Little Prince        2015   81200000    1339152
# 22                         Hugo        2011  170000000   73820094
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 99       Katrina Bowden        Tyler Labine          Chelan Simmons
# ...

# %%
Vdf_negativeprofit.plot(x='title_year', y=['budget','profit'], kind='bar')
# Out:
# <Axes: xlabel='title_year'>

# %%
Vdf_negativeprofit['title_year'].value_counts().plot(kind='bar')
# df['season'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='title_year'>

# %%
# Change the scale of MetaCritic
Vdf['MetaCritic_10'] = Vdf['MetaCritic']/10
Vdf[['MetaCritic','MetaCritic_10']]
# Out:
#     MetaCritic  MetaCritic_10
# 94       100.0           10.0
# 69        96.0            9.6
# 18        94.0            9.4
# 12        92.0            9.2
# 4         96.0            9.6
# ..         ...            ...
# 16         NaN            NaN
# 52         NaN            NaN
# 88         NaN            NaN
# 71         NaN            NaN
# 82         NaN            NaN
#
# [100 rows x 2 columns]

# %%
# Find the average ratings
Vdf['Average_rating'] = (Vdf['MetaCritic_10']+Vdf['IMDb_rating'])/2
Vdf[['MetaCritic_10','IMDb_rating','Average_rating']]
# Out:
#     MetaCritic_10  IMDb_rating  Average_rating
# 94           10.0          7.9            8.95
# 69            9.6          8.1            8.85
# 18            9.4          8.2            8.80
# 12            9.2          8.3            8.75
# 4             9.6          7.9            8.75
# ..            ...          ...             ...
# 16            NaN          7.9             NaN
# 52            NaN          7.5             NaN
# 88            NaN          7.8             NaN
# 71            NaN          7.6             NaN
# 82            NaN          7.7             NaN
#
# [100 rows x 3 columns]

# %%
Vdf.Average_rating.describe()
# Out:
# count    95.000000
# mean      7.858947
# std       0.488374
# min       6.950000
# 25%       7.475000
# 50%       7.850000
# 75%       8.125000
# max       8.950000
# Name: Average_rating, dtype: float64

# %%
#Sort in descending order of average rating
Vdf.sort_values('Average_rating',ascending=False,inplace=True)
Vdf['Average_rating']
# Out:
# 94    8.95
# 69    8.85
# 18    8.80
# 12    8.75
# 4     8.75
#       ...
# 16     NaN
# 52     NaN
# 88     NaN
# 71     NaN
# 82     NaN
# Name: Average_rating, Length: 100, dtype: float64

# %%
#Retain only the movies in which the absolute difference(using abs() function) between the IMDb_rating and Metacritic columns is less than 0.5.
Vdf_movies = Vdf[abs(Vdf['MetaCritic_10']-Vdf['IMDb_rating'])<0.5]
# Vdf_movies.sort_values('Average_rating',ascending=False)
UniversalAcclaim = Vdf_movies[Vdf_movies['Average_rating']>=8].sort_values('Average_rating',ascending=False)
UniversalAcclaim
# Out:
#                                          Title  title_year  budget  \
# 95                                    Whiplash        2014     3.3
# 35                            Django Unchained        2012   100.0
# 93                          Dallas Buyers Club        2013     5.0
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 3                                      Arrival        2016    47.0
# 43                                   Gone Girl        2014    61.0
# 33                                 The Martian        2015   108.0
#
#          Gross         actor_1_name     actor_2_name       actor_3_name  \
# 95   13.092000         J.K. Simmons  Melissa Benoist       Chris Mulkey
# 35  162.804648    Leonardo DiCaprio  Christoph Waltz       Ato Essandoh
# 93   27.296514  Matthew McConaughey  Jennifer Garner       Denis O'Hare
# 97  936.662225          Doug Walker       Rob Walker                  0
# ...

# %% [markdown]
# Subtask 2.4: Find the Most Popular Trios - I
# You're a producer looking to make a blockbuster movie. There will primarily be three lead roles in your movie and you wish to cast the most popular actors for it. Now, since you don't want to take a risk, you will cast a trio which has already acted in together in a movie before. The metric that you've chosen to check the popularity is the Facebook likes of each of these actors.
#
# The dataframe has three columns to help you out for the same, viz. actor_1_facebook_likes, actor_2_facebook_likes, and actor_3_facebook_likes. Your objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of actor_1_facebook_likes, actor_2_facebook_likes and actor_3_facebook_likes should be maximum. Find out the top 5 popular trios, and output their names in a list.

# %%
Vdf_trios = Vdf[['actor_1_name','actor_2_name','actor_3_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']]
Vdf_trios
# Out:
#           actor_1_name        actor_2_name    actor_3_name  \
# 94      Ellar Coltrane   Lorelei Linklater   Libby Villari
# 69  QuvenzhanÃ© Wallis       Scoot McNairy    Taran Killam
# 18         Amy Poehler        Mindy Kaling   Phyllis Smith
# 12           Tom Hanks   John Ratzenberger     Don Rickles
# 4        Casey Affleck  Michelle Williams    Kyle Chandler
# ..                 ...                 ...             ...
# 16        Aidan Turner          Adam Brown   James Nesbitt
# 52       Jerry Ferrara         Scott Elrod   Dan Bilzerian
# 88          Tom Hughes       Tom Hollander  Lindsay Duncan
# 71        Emily Watson     Sophie NÃ©lisse     Roger Allam
# 82    Madeline Carroll   Rebecca De Mornay     Aidan Quinn
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes
# 94                     230                   193.0                   127.0
# 69                    2000                   660.0                   500.0
# ...

# %%
Vdf = Vdf.sort_index()
Vdf
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
Vdf_trios = Vdf[['actor_1_name','actor_2_name','actor_3_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']]
Vdf_trios
# Out:
#                 actor_1_name        actor_2_name            actor_3_name  \
# 0               Ryan Gosling          Emma Stone              Amiée Conn
# 1           Ginnifer Goodwin       Jason Bateman              Idris Elba
# 2                  Dev Patel       Nicole Kidman             Rooney Mara
# 3                  Amy Adams       Jeremy Renner         Forest Whitaker
# 4              Casey Affleck  Michelle Williams            Kyle Chandler
# ..                       ...                 ...                     ...
# 95              J.K. Simmons     Melissa Benoist            Chris Mulkey
# 96  Seamus Davey-Fitzpatrick        Ariane Labed  Athina Rachel Tsangari
# 97               Doug Walker          Rob Walker                       0
# 98              Rupert Grint          Toby Jones            Alfred Enoch
# 99            Katrina Bowden        Tyler Labine          Chelan Simmons
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes
# ...

# %%
Vdf['total_facebook_likes'] = Vdf['actor_1_facebook_likes']+Vdf['actor_2_facebook_likes']+Vdf['actor_3_facebook_likes']
Vdf[['actor_1_name','actor_2_name','actor_3_name','total_facebook_likes']]
# Out:
#             actor_1_name        actor_2_name          actor_3_name  \
# 2              Dev Patel       Nicole Kidman           Rooney Mara
# 27     Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14     Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4          Casey Affleck  Michelle Williams          Kyle Chandler
# 8              Tom Hardy      Christian Bale  Joseph Gordon-Levitt
# ..                   ...                 ...                   ...
# 97           Doug Walker          Rob Walker                     0
# 34        Phaldut Sharma       Basher Savage            Amy Warren
# 0           Ryan Gosling          Emma Stone            Amiée Conn
# 3              Amy Adams       Jeremy Renner       Forest Whitaker
# 6   Benedict Cumberbatch    Chiwetel Ejiofor        Rachel McAdams
#
#     total_facebook_likes
# 2               138800.0
# 27               79000.0
# 14               76000.0
# 4                74818.0
# 8                73000.0
# ...

# %%
Vdf_sorted = Vdf.sort_values('total_facebook_likes', ascending=False)
Vdf_sorted
# Out:
#                                          Title  title_year  budget  \
# 2                                         Lion        2016    12.0
# 27                                   Inception        2010   160.0
# 14                  X-Men: Days of Future Past        2014   200.0
# 4                        Manchester by the Sea        2016     9.0
# 8                        The Dark Knight Rises        2012   250.0
# ..                                         ...         ...     ...
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 34                                     Gravity        2013   100.0
# 0                                   La La Land        2016    30.0
# 3                                      Arrival        2016    47.0
# 6                               Doctor Strange        2016   165.0
#
#          Gross          actor_1_name        actor_2_name  \
# 2    51.738905             Dev Patel       Nicole Kidman
# ...

# %%
top5_trios = Vdf_sorted.head(5)
top5_trios
# Out:
#                          Title  title_year  budget       Gross  \
# 2                         Lion        2016    12.0   51.738905
# 27                   Inception        2010   160.0  292.568851
# 14  X-Men: Days of Future Past        2014   200.0  233.914986
# 4        Manchester by the Sea        2016     9.0   47.695371
# 8        The Dark Knight Rises        2012   250.0  448.130642
#
#          actor_1_name        actor_2_name          actor_3_name  \
# 2           Dev Patel       Nicole Kidman           Rooney Mara
# 27  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4       Casey Affleck  Michelle Williams          Kyle Chandler
# 8           Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 2                    33000                 96000.0                  9800.0
# ...

# %%
top5_trios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 2 to 8
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   5 non-null      object
#  1   title_year              5 non-null      int64
#  2   budget                  5 non-null      float64
#  3   Gross                   5 non-null      float64
#  4   actor_1_name            5 non-null      object
#  5   actor_2_name            5 non-null      object
#  6   actor_3_name            5 non-null      object
#  7   actor_1_facebook_likes  5 non-null      int64
#  8   actor_2_facebook_likes  5 non-null      float64
#  9   actor_3_facebook_likes  5 non-null      float64
#  10  IMDb_rating             5 non-null      float64
#  11  genre_1                 5 non-null      object
#  12  genre_2                 4 non-null      object
#  13  genre_3                 2 non-null      object
# ...

# %%
top5_trios_1 = Vdf.nlargest(5, 'total_facebook_likes')[['actor_1_name', 'actor_2_name', 'actor_3_name']]
top5_trios_1
# Out:
#          actor_1_name        actor_2_name          actor_3_name
# 2           Dev Patel       Nicole Kidman           Rooney Mara
# 27  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4       Casey Affleck  Michelle Williams          Kyle Chandler
# 8           Tom Hardy      Christian Bale  Joseph Gordon-Levitt

# %%
top5_list = top5_trios_1.values.tolist()
top5_list
# Out:
# [['Dev Patel', 'Nicole Kidman', 'Rooney Mara'],
#  ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman'],
#  ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler'],
#  ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']]

# %%
for top5_list in top5_list:
  print(top5_list)
# Out:
# ['Dev Patel', 'Nicole Kidman', 'Rooney Mara']
# ['Leonardo DiCaprio', 'Tom Hardy', 'Joseph Gordon-Levitt']
# ['Jennifer Lawrence', 'Peter Dinklage', 'Hugh Jackman']
# ['Casey Affleck', 'Michelle Williams ', 'Kyle Chandler']
# ['Tom Hardy', 'Christian Bale', 'Joseph Gordon-Levitt']

# %%
Vdf.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country', 'profit', 'MetaCritic_10',
# ...

# %% [markdown]
# Subtask 2.5: Find the Most Popular Trios - II
# In the previous subtask you found the popular trio based on the total number of facebook likes. Let's add a small condition to it and make sure that all three actors are popular. The condition is none of the three actors' Facebook likes should be less than half of the other two. For example, the following is a valid combo:
#
# actor_1_facebook_likes: 70000
# actor_2_facebook_likes: 40000
# actor_3_facebook_likes: 50000
# But the below one is not:
#
# actor_1_facebook_likes: 70000
# actor_2_facebook_likes: 40000
# actor_3_facebook_likes: 30000
# since in this case, actor_3_facebook_likes is 30000, which is less than half of actor_1_facebook_likes.
#
# Having this condition ensures that you aren't getting any unpopular actor in your trio (since the total likes calculated in the previous question doesn't tell anything about the individual popularities of each actor in the trio.).
#
# You can do a manual inspection of the top 5 popular trios you have found in the previous subtask and check how many of those trios satisfy this condition. Also, which is the most popular trio after applying the condition above?

# %%
top5_trios
# Out:
#                          Title  title_year     budget      Gross  \
# 2                         Lion        2016   12000000   51738905
# 27                   Inception        2010  160000000  292568851
# 14  X-Men: Days of Future Past        2014  200000000  233914986
# 4        Manchester by the Sea        2016    9000000   47695371
# 8        The Dark Knight Rises        2012  250000000  448130642
#
#          actor_1_name        actor_2_name          actor_3_name  \
# 2           Dev Patel       Nicole Kidman           Rooney Mara
# 27  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4       Casey Affleck  Michelle Williams          Kyle Chandler
# 8           Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 2                    33000                 96000.0                  9800.0
# ...

# %%
balanced_trios = top5_trios[
    (top5_trios[['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']].min(axis=1) >=
     0.5 * top5_trios[['actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']].max(axis=1))
]
balanced_trios
# Out:
#                          Title  title_year  budget       Gross  \
# 27                   Inception        2010   160.0  292.568851
# 14  X-Men: Days of Future Past        2014   200.0  233.914986
# 8        The Dark Knight Rises        2012   250.0  448.130642
#
#          actor_1_name    actor_2_name          actor_3_name  \
# 27  Leonardo DiCaprio       Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence  Peter Dinklage          Hugh Jackman
# 8           Tom Hardy  Christian Bale  Joseph Gordon-Levitt
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 27                   29000                 27000.0                 23000.0
# 14                   34000                 22000.0                 20000.0
# 8                    27000                 23000.0                 23000.0
#
#     ...  Votes45AF Votes1000 VotesUS VotesnUS  content_rating  Country  \
# 27  ...        8.0       8.2     8.7      8.8           PG-13      USA
# ...

# %%
balanced_trios.shape[0]
# Out:
# 3

# %%
len(balanced_trios)
# Out:
# 3

# %%
print('Total Movies',len(balanced_trios))
print('Movie Names',balanced_trios['Title'].tolist())
# Out:
# Total Movies 3
# Movie Names ['Inception', 'X-Men: Days of Future Past', 'The Dark Knight Rises']

# %% [markdown]
# Subtask 2.6: Runtime Analysis
# There is a column named Runtime in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Plot a histogram or distplot of seaborn to find the Runtime range most of the movies fall into.

# %%
sns.distplot(Vdf['Runtime'], hist = False )
plt.show()

# %%
sns.distplot(Vdf['Runtime'], hist = True )
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(Vdf['Runtime'], kde=True, color='teal', bins=20)
plt.title('Distribution of Movie Runtime')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Subtask 2.7: R-Rated Movies
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest number of votes i.e.CVotesU18 from the movies dataframe. Store these in a dataframe named PopularR.

# %%
Vdf
# Out:
#                                          Title  title_year  budget  \
# 2                                         Lion        2016    12.0
# 27                                   Inception        2010   160.0
# 14                  X-Men: Days of Future Past        2014   200.0
# 4                        Manchester by the Sea        2016     9.0
# 8                        The Dark Knight Rises        2012   250.0
# ..                                         ...         ...     ...
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 34                                     Gravity        2013   100.0
# 0                                   La La Land        2016    30.0
# 3                                      Arrival        2016    47.0
# 6                               Doctor Strange        2016   165.0
#
#          Gross          actor_1_name        actor_2_name  \
# 2    51.738905             Dev Patel       Nicole Kidman
# ...

# %%
R_rated_movies = Vdf[(Vdf['content_rating'] == 'R')]
R_rated_movies
# Out:
#                                               Title  title_year  budget  \
# 4                             Manchester by the Sea        2016     9.0
# 68                          Silver Linings Playbook        2012    21.0
# 62                                    The Big Short        2015    28.0
# 31                                     The Revenant        2015   135.0
# 36                          The Wolf of Wall Street        2013   100.0
# 35                                 Django Unchained        2012   100.0
# 5                                Hell or High Water        2016    12.0
# 29                               Mad Max: Fury Road        2015   150.0
# 56                                             Rush        2013    38.0
# 83                                       Black Swan        2010    13.0
# 50                                        Prisoners        2013    46.0
# 91                                            50/50        2011     8.0
# ...

# %%
PopularR = R_rated_movies.sort_values('CVotesU18',ascending=False)
PopularR.head(10)
# Out:
#                                               Title  title_year  budget  \
# 47                                         Deadpool        2016    58.0
# 36                          The Wolf of Wall Street        2013   100.0
# 35                                 Django Unchained        2012   100.0
# 29                               Mad Max: Fury Road        2015   150.0
# 95                                         Whiplash        2014     3.3
# 31                                     The Revenant        2015   135.0
# 40                                   Shutter Island        2010    80.0
# 43                                        Gone Girl        2014    61.0
# 65                         The Grand Budapest Hotel        2014    25.0
# 72  Birdman or (The Unexpected Virtue of Ignorance)        2014    18.0
#
#          Gross       actor_1_name         actor_2_name       actor_3_name  \
# 47  363.024263      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# ...

# %% [markdown]
# Subtask 3.1 Combine the Dataframe by Genres
# There are 3 columns in the dataframe - genre_1, genre_2, and genre_3. As a part of this subtask, you need to aggregate a few values over these 3 columns.
#
# First create a new dataframe df_by_genre that contains genre_1, genre_2, and genre_3 and all the columns related to CVotes/Votes from the movies data frame. There are 47 columns to be extracted in total.

# %%
cols = ['genre_1', 'genre_2', 'genre_3'] + [col for col in Vdf.columns if 'CVotes' in col or 'Votes' in col]
df_by_genre = Vdf[cols].copy()
df_by_genre
# Out:
#       genre_1    genre_2   genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 2   Biography      Drama       NaN     23325     29830     40564     20296
# 27     Action  Adventure    Sci-Fi    584839    485218    304457    130972
# 14     Action  Adventure    Sci-Fi     91765    127521    183578    104658
# 4       Drama        NaN       NaN     18191     33532     46596     29626
# 8      Action   Thriller       NaN    380589    341965    281426    134959
# ..        ...        ...       ...       ...       ...       ...       ...
# 97     Action  Adventure   Fantasy    155391    161810    166378     99402
# 34      Drama     Sci-Fi  Thriller     89986    127616    169693    122275
# 0      Comedy      Drama     Music     74245     71191     64640     38831
# 3       Drama    Mystery    Sci-Fi     55533     87850    109536     65440
# 6      Action  Adventure   Fantasy     38952     51465    102744     83322
#
# ...

# %% [markdown]
# -  ###  Subtask 3.1 Combine the Dataframe by Genres
#
# There are 3 columns in the dataframe - `genre_1`, `genre_2`, and `genre_3`. As a part of this subtask, you need to aggregate a few values over these 3 columns.
# 1. First create a new dataframe `df_by_genre` that contains `genre_1`, `genre_2`, and `genre_3` and all the columns related to **CVotes/Votes** from the `movies` data frame. There are 47 columns to be extracted in total.
# 2. Now, Add a column called `cnt` to the dataframe `df_by_genre` and initialize it to one. You will realise the use of this column by the end of this subtask.
# 3. First group the dataframe `df_by_genre` by `genre_1` and find the sum of all the numeric columns such as `cnt`, columns related to CVotes and Votes columns and store it in a dataframe `df_by_g1`.
# 4. Perform the same operation for `genre_2` and `genre_3` and store it dataframes `df_by_g2` and `df_by_g3` respectively.
# 5. Now that you have 3 dataframes performed by grouping over `genre_1`, `genre_2`, and `genre_3` separately, it's time to combine them. For this, add the three dataframes and store it in a new dataframe `df_add`, so that the corresponding values of Votes/CVotes get added for each genre.There is a function called `add()` in pandas which lets you do this. You can refer to this link to see how this function works. https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.add.html
# 6. The column `cnt` on aggregation has basically kept the track of the number of occurences of each genre.Subset the genres that have atleast 10 movies into a new dataframe `genre_top10` based on the `cnt` column value.
# 7. Now, take the mean of all the numeric columns by dividing them with the column value `cnt` and store it back to the same dataframe. We will be using this dataframe for further analysis in this task unless it is explicitly mentioned to use the dataframe `movies`.
# 8. Since the number of votes can't be a fraction, type cast all the CVotes related columns to integers. Also, round off all the Votes related columns upto two digits after the decimal point.

# %%
df_by_genre['cnt'] = 1
df_by_genre.columns
# Out:
# Index(['genre_1', 'genre_2', 'genre_3', 'CVotes10', 'CVotes09', 'CVotes08',
#        'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04', 'CVotes03', 'CVotes02',
#        'CVotes01', 'CVotesMale', 'CVotesFemale', 'CVotesU18', 'CVotesU18M',
#        'CVotesU18F', 'CVotes1829', 'CVotes1829M', 'CVotes1829F', 'CVotes3044',
#        'CVotes3044M', 'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF',
#        'CVotes1000', 'CVotesUS', 'CVotesnUS', 'VotesM', 'VotesF', 'VotesU18',
#        'VotesU18M', 'VotesU18F', 'Votes1829', 'Votes1829M', 'Votes1829F',
#        'Votes3044', 'Votes3044M', 'Votes3044F', 'Votes45A', 'Votes45AM',
#        'Votes45AF', 'Votes1000', 'VotesUS', 'VotesnUS', 'cnt'],
#       dtype='object')

# %%
df_by_g1 = df_by_genre.groupby('genre_1').sum(numeric_only=True)
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# ...

# %%
df_by_g2 = df_by_genre.groupby('genre_2').sum(numeric_only=True)
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
df_by_g3 = df_by_genre.groupby('genre_3').sum(numeric_only=True)
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
df_add = df_by_g1.add(df_by_g2, fill_value=0).add(df_by_g3, fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
genre_top10 = df_add[df_add['cnt']>10]
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
genre_top10.iloc[:,0:-1 ] = genre_top10.iloc[:,0:-1 ].divide(genre_top10['cnt'], axis=0)
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
genre_top10 = genre_top10.div(genre_top10['cnt'], axis=0)
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
genre_top10.iloc[:,0:-1 ]
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes1829F  Votes3044  \
# Action         5386      3064      2115      5524  ...        8.00       7.74
# ...

# %%
def format_votes(coln):
    if 'CVotes' in coln.name:
        return coln.astype(int)
    elif 'Votes' in coln.name:
        return coln.round(2)
    else:
        return coln

genre_top10 = genre_top10.apply(format_votes)
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action         5386      3064      2115      5524  ...       7.74        7.73
# ...

# %% [markdown]
# Subtask 3.2: Genre Counts!
# Now let's derive some insights from this data frame. Make a bar chart plotting different genres vs cnt using seaborn.

# %%
genre_top10.columns
# Out:
# Index(['CVotes10', 'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05',
#        'CVotes04', 'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale',
#        'CVotesFemale', 'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829',
#        'CVotes1829M', 'CVotes1829F', 'CVotes3044', 'CVotes3044M',
#        'CVotes3044F', 'CVotes45A', 'CVotes45AM', 'CVotes45AF', 'CVotes1000',
#        'CVotesUS', 'CVotesnUS', 'VotesM', 'VotesF', 'VotesU18', 'VotesU18M',
#        'VotesU18F', 'Votes1829', 'Votes1829M', 'Votes1829F', 'Votes3044',
#        'Votes3044M', 'Votes3044F', 'Votes45A', 'Votes45AM', 'Votes45AF',
#        'Votes1000', 'VotesUS', 'VotesnUS', 'cnt'],
#       dtype='object')

# %%
genre_top10 = genre_top10.reset_index()
genre_top10
# Out:
#        index       CVotes10       CVotes09       CVotes08       CVotes07  \
# 0     Action  102144.096774  114433.193548  150895.322581   94262.129032
# 1  Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# 2  Animation   61960.181818   72566.090909  104837.636364   65707.454545
# 3  Biography   47333.500000   77867.111111  123948.777778   74054.444444
# 4     Comedy   60157.217391   77173.347826  108993.521739   69176.913043
# 5      Crime   52229.636364   87919.818182  129045.000000   74671.818182
# 6      Drama   52375.969231   75928.846154  109339.276923   66456.923077
# 7    Romance   42304.538462   53037.846154   82252.307692   54833.923077
# 8     Sci-Fi  136781.411765  148873.823529  176646.705882  106005.764706
# 9   Thriller   83207.769231  112730.076923  153336.769231   90446.076923
#
#        CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  ...  \
# 0  34688.838710  12693.032258  5386.129032  3064.645161  2115.258065  ...
# ...

# %%
genre_top10.rename(columns={'index': 'Genre'}, inplace=True)
genre_top10
# Out:
#        Genre       CVotes10       CVotes09       CVotes08       CVotes07  \
# 0     Action  102144.096774  114433.193548  150895.322581   94262.129032
# 1  Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# 2  Animation   61960.181818   72566.090909  104837.636364   65707.454545
# 3  Biography   47333.500000   77867.111111  123948.777778   74054.444444
# 4     Comedy   60157.217391   77173.347826  108993.521739   69176.913043
# 5      Crime   52229.636364   87919.818182  129045.000000   74671.818182
# 6      Drama   52375.969231   75928.846154  109339.276923   66456.923077
# 7    Romance   42304.538462   53037.846154   82252.307692   54833.923077
# 8     Sci-Fi  136781.411765  148873.823529  176646.705882  106005.764706
# 9   Thriller   83207.769231  112730.076923  153336.769231   90446.076923
#
#        CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  ...  \
# 0  34688.838710  12693.032258  5386.129032  3064.645161  2115.258065  ...
# ...

# %%
sns.countplot(x='Genre',data=genre_top10)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
df_add = df_add.drop(columns=['Genre'])

# %%
df_add.rename(columns={'index': 'Genres'}, inplace=True)
df_add
# Out:
#     Genres   CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# 0        0  3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# 1        1  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# 2        2   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# 3        3   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# 4        4  1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# 5        5   574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# 6        6  3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# 7        7    98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# 8        8   572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# 9        9   151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# 10      10    16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
plt.figure(figsize=(20,6))
sns.barplot(x = 'Genres', y = 'cnt',  data = df_add )
plt.title('Genres vs Count')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4135677485.py in <cell line: 0>()
#       1 plt.figure(figsize=(20,6))
# ----> 2 sns.barplot(x = 'Genres', y = 'cnt',  data = df_add )
#       3 plt.title('Genres vs Count')
#       4 plt.xlabel('Genres')
#       5 plt.ylabel('Count')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2339         estimator = "size"
#    2340
# -> 2341     p = _CategoricalAggPlotter(
#    2342         data=data,
#    2343         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#
# ...

# %%
# plt.figure(figsize = (20,20))
# sns.heatmap(df_add[['CVotesU18M','CVotes1829M','CVotes3044F','CVotes45AF']], annot = True, cmap = 'Greens')
male_cols = ['CVotesU18M','CVotes1829M','CVotes3044F','CVotes45AF']
df_male = genre_top10.set_index('Genre')[male_cols]
df_male
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1085043995.py in <cell line: 0>()
#       2 # sns.heatmap(df_add[['CVotesU18M','CVotes1829M','CVotes3044F','CVotes45AF']], annot = True, cmap = 'Greens')
#       3 male_cols = ['CVotesU18M','CVotes1829M','CVotes3044F','CVotes45AF']
# ----> 4 df_male = genre_top10.set_index('Genre')[male_cols]
#       5 df_male
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Genre'] are in the columns"

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_male, annot=True, cmap='Blues')
plt.title('Average Number of Male Votes by Genre and Age Group')
plt.xlabel('Age Group')
plt.ylabel('Genre')
plt.show()

# %%
sns.heatmap(df_add[['CVotesU18M','CVotes1829M','CVotes3044M','CVotes45AM']], annot = True, cmap = 'Greens')
# Out:
# <Axes: >

# %%
female_cols = ['CVotesU18F', 'CVotes1829F', 'CVotes3044F', 'CVotes45AF']
df_female = genre_top10.set_index('Genre')[female_cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1774415066.py in <cell line: 0>()
#       1 female_cols = ['CVotesU18F', 'CVotes1829F', 'CVotes3044F', 'CVotes45AF']
# ----> 2 df_female = genre_top10.set_index('Genre')[female_cols]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Genre'] are in the columns"

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# Male heatmap

#sns.heatmap(df_male, annot=True, cmap='Blues', ax=axes[0])
sns.heatmap(df_male, annot=True, fmt='.0f', cmap='Blues', ax=axes[0])
axes[0].set_title('Average Male Votes by Genre and Age Group')
axes[0].set_xlabel('Age Group')
axes[0].set_ylabel('Genre')

# Female heatmap
sns.heatmap(df_female, annot=True, fmt='.0f', cmap='Reds', ax=axes[1])
#sns.heatmap(df_female, annot=True, cmap='Reds', ax=axes[1])
axes[1].set_title('Average Female Votes by Genre and Age Group')
axes[1].set_xlabel('Age Group')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Males consistently vote more than females
# The 18–29 male group dominates engagement
# Sci-Fi, Action, and Adventure attract the highest overall engagement
# Female engagement mirrors male trends, but at lower volume
# Low engagement from older and under-18 groups

# %%
female_cols_vote = [	'Votes3044F',		'Votes45AF'	]
df_female_vote = genre_top10.set_index('Genre')[female_cols_vote]
df_female_vote
# Out:
#            Votes3044F  Votes45AF
# Genre
# Action           7.80       7.75
# Adventure        7.87       7.84
# Animation        7.98       7.88
# Biography        7.77       7.87
# Comedy           7.75       7.70
# Crime            7.61       7.68
# Drama            7.72       7.74
# Romance          7.66       7.61
# Sci-Fi           7.84       7.74
# Thriller         7.70       7.75

# %%
male_cols_vote = ['Votes3044M',	'Votes45AM',	]
df_male_vote = genre_top10.set_index('Genre')[male_cols_vote]
df_male_vote
# Out:
#            Votes3044M  Votes45AM
# Genre
# Action           7.73       7.63
# Adventure        7.73       7.64
# Animation        7.72       7.65
# Biography        7.72       7.66
# Comedy           7.71       7.60
# Crime            7.76       7.62
# Drama            7.71       7.62
# Romance          7.61       7.50
# Sci-Fi           7.85       7.69
# Thriller         7.75       7.64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# Male heatmap

sns.heatmap(df_male_vote, annot=True, cmap='Blues', ax=axes[0])

axes[0].set_title('Average Male Votes by Genre and Age Group')
axes[0].set_xlabel('Age Group')
axes[0].set_ylabel('Genre')

# Female heatmap
sns.heatmap(df_female_vote, annot=True, cmap='Reds', ax=axes[1])
axes[1].set_title('Average Female Votes by Genre and Age Group')
axes[1].set_xlabel('Age Group')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1.Female audiences rate slightly higher overall
# 2.Animation, Adventure, and Biography are female favorites
# 3.Males show a stronger liking for Crime and Sci-Fi
# 4.Both genders rate fairly consistently

# %%
Vdf
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
import numpy as np

Vdf['IFUS'] = np.where(Vdf['Country'] == 'USA', 'USA', 'Non-USA')
Vdf[['IFUS','Country']]
# Out:
#        IFUS    Country
# 0       USA        USA
# 1       USA        USA
# 2   Non-USA  Australia
# 3       USA        USA
# 4       USA        USA
# ..      ...        ...
# 95      USA        USA
# 96      USA        USA
# 97      USA        USA
# 98  Non-USA         UK
# 99  Non-USA     Canada
#
# [100 rows x 2 columns]

# %%
Vdf['IFUS'] = Vdf['Country'].apply(lambda x: 'USA' if x == 'USA' else 'Non-USA')

# %%
plt.figure(figsize=(14,6))

plt.subplot(1,2,1)
sns.boxplot(x='IFUS', y='CVotesUS', data=Vdf, palette='cool')
plt.title('Distribution of US Votes for US vs Non-US Movies')
plt.xlabel('Movie Origin')
plt.ylabel('Votes from US Users')


plt.subplot(1,2,2)
sns.boxplot(x='IFUS', y='CVotesnUS', data=Vdf, palette='autumn')
plt.title('Distribution of Non-US Votes for US vs Non-US Movies')
plt.xlabel('Movie Origin')
plt.ylabel('Votes from Non-US Users')

plt.tight_layout()
plt.show()

# %%
genre_top10
# Out:
#    level_0      Genre  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  \
# 0        0     Action    102144    114433    150895     94262     34688
# 1        1  Adventure     94596    105636    138482     86367     31896
# 2        2  Animation     61960     72566    104837     65707     22825
# 3        3  Biography     47333     77867    123948     74054     23644
# 4        4     Comedy     60157     77173    108993     69176     26099
# 5        5      Crime     52229     87919    129045     74671     25308
# 6        6      Drama     52375     75928    109339     66456     23528
# 7        7    Romance     42304     53037     82252     54833     21637
# 8        8     Sci-Fi    136781    148873    176646    106005     39518
# 9        9   Thriller     83207    112730    153336     90446     32003
#
#    CVotes05  CVotes04  CVotes03  ...  Votes3044  Votes3044M  Votes3044F  \
# 0     12693      5386      3064  ...       7.74        7.73        7.80
# ...

# %%
genre_top10.sort_values('CVotes1000',ascending=False)
genre_top10[['Genre','CVotes1000']].sort_values('CVotes1000',ascending=False)
# Out:
#        Genre  CVotes1000
# 8     Sci-Fi         714
# 0     Action         681
# 9   Thriller         669
# 1  Adventure         662
# 5      Crime         620
# 4     Comedy         605
# 3  Biography         600
# 6      Drama         585
# 2  Animation         578
# 7    Romance         548

# %%
plt.figure(figsize=(20,6))
sns.barplot( x ='Genre', y ='CVotes1000',data=genre_top10)
# Out:
# <Axes: xlabel='Genre', ylabel='CVotes1000'>

# %% [markdown]
# Sci-Fi is most popular among the top 1000 votes and Romance is the most unpopular.
