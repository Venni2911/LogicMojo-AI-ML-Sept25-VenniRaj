# %% [markdown]
# <a href="https://colab.research.google.com/github/Venni2911/LogicMojo-AI-ML-Sept25-VenniRaj/blob/main/copy%20of%20Churn_Modelling_dataset_for_Tree_based_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The problem statement for this use case entails developing a predictive model
# to forecast customer churn within a business context. Customer churn, or the attrition of customers from a company's clientele, poses a significant challenge to businesses across various industries.
#
# The primary objective is to employ machine learning algorithms, particularly tree-based models such as decision trees, random forests, and gradient boosting classifiers, to analyze historical customer data and predict the likelihood of churn for individual customers.
#
# Through the utilization of a dataset containing relevant customer attributes, including but not limited to demographic information, usage patterns, and account features, the goal is to discern underlying patterns and relationships that contribute to customer churn.
#
# By accurately predicting which customers are at risk of churning, organizations can proactively implement targeted retention strategies aimed at preserving customer loyalty and enhancing overall business performance.

# %% [markdown]
# https://www.google.com/url?q=https%3A%2F%2Fdrive.google.com%2Ffile%2Fd%2F1MEm750oJYJz6FbpSEVJ1IlNSxnuwcWH7%2Fview%3Fusp%3Dsharing

# %%
###1. basic EDA

# %%
### 2. Feature Engineering - Outlier analysis, categorical variable encoding, scaling
### 3. Train Test split and Fit you base model - Logistical Regression model and  basic DT using Grid Search CV
### 4. Random Forrest fitting
#### 5. Boosying model - Adaboost and XG boost -> Also see the time it takes to train the model
### 6. Compare the outputs of each using barchart
