# %% [markdown]
# <a href="https://colab.research.google.com/github/Venni2911/LogicMojo-AI-ML-Sept25-VenniRaj/blob/main/Intro_to_NLP_and_Text_processing_topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Intro to NLP and Text processing topic**

# %% [markdown]
# # **Agenda**
# * **Intro to NLP and Text processing topic**
# * **Text Processing Techniques**
# * **Text Representation**
# * **Deep Learning Models for NLP**
# * **Applications of NLP**
# * **NLP Pipelines and Frameworks**

# %% [markdown]
# # **Intro to NLP and Text processing topic**

# %% [markdown]
# - Introduction to Natural Language Processing (NLP) and Text Processing in Deep Learning
# Natural Language Processing (NLP) is a field at the intersection of computer science, artificial intelligence, and linguistics. It involves the development of algorithms and models that enable computers to understand, interpret, and generate human language. Text processing is a crucial part of NLP that deals with the manipulation and analysis of text data. Deep learning, with its ability to model complex patterns, has significantly advanced the field of NLP.

# %% [markdown]
# ###**Basics of NLP**
# **Definition and Importance**
# - Natural Language Processing (NLP) is a field of artificial intelligence that focuses on enabling machines to understand, interpret, and respond to human languages.
#
# **Its significance lies in a broad range of applications, including:**
# - **Chatbots:** Automated systems that can interact with users via text or speech.
# - **Machine Translation:** Systems that translate text from one language to another.
# - **Sentiment Analysis:** Techniques to determine the emotional tone behind a series of words.
#
# **Key Challenges in NLP**
# - **Ambiguity:**
# Words and sentences can have multiple meanings depending on their context.
# - **Example:** The word "bat" can refer to an animal or a piece of sports equipment.
# Context:
#
# **Understanding the context is crucial for accurate interpretation.**
# - **Example:** "He saw the man with the telescope" can mean either the man had the telescope or the observer used the telescope.
#
# - **Variability:**
# Language is highly variable and constantly evolving.
# Example: New slang and idioms emerge regularly, and different dialects and accents can make understanding more complex.

# %% [markdown]
# ###**Visualization of NLP Basics**

# %%
pip install matplotlib networkx

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes for NLP Basics
G.add_node('NLP', label='NLP Definition: Enabling machines to understand and process human languages.')

# Add nodes for Importance
G.add_node('Importance', label='Importance: Applications range from chatbots to machine translation and sentiment analysis.')

# Add nodes for Key Challenges
G.add_node('Challenges', label='Key Challenges in NLP')
G.add_node('Ambiguity', label='Ambiguity: Words and sentences can have multiple meanings.')
G.add_node('Context', label='Context: Understanding the context is crucial for accurate interpretation.')
G.add_node('Variability', label='Variability: Language is highly variable and constantly evolving.')

# Add edges to show connections
G.add_edge('NLP', 'Importance')
G.add_edge('NLP', 'Challenges')
G.add_edge('Challenges', 'Ambiguity')
G.add_edge('Challenges', 'Context')
G.add_edge('Challenges', 'Variability')

# Get labels for the nodes
labels = nx.get_node_attributes(G, 'label')

# Draw the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G, seed=42)  # Layout for a visually pleasing arrangement

# Draw the nodes and edges
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=10, font_weight='bold', arrowsize=18)
nx.draw_networkx_labels(G, pos, labels=labels, font_size=)

# Show the plot
plt.title('Basics of NLP')
plt.show()

# %% [markdown]
# # **Text Processing Techniques**

# %% [markdown]
# ####**Tokenization**
# - Tokenization involves breaking down text into smaller units called tokens, which can be individual words or sentences.
#
# - **Word Tokenization:** This process involves splitting a sentence into individual words. For example, the sentence "I love natural language processing" would be tokenized into ["I", "love", "natural", "language", "processing"].
#
# - **Sentence Tokenization:** This process involves dividing a paragraph or text into individual sentences. For example, the paragraph "I love natural language processing. It's fascinating. I study it every day." would be tokenized into ["I love natural language processing.", "It's fascinating.", "I study it every day."].

# %% [markdown]
# ####**Normalization**
# Normalization is the process of converting text to a standard format, which makes it easier to process and analyze.
#
# - **Lowercasing:** This involves converting all characters in the text to lowercase to ensure uniformity. For example, "Text Processing" becomes "text processing".
# - **Stemming:** This involves reducing words to their root forms, which may not be a valid word. For example, "running" might be reduced to "run".
# - **Lemmatization:** This involves reducing words to their base or dictionary form. Unlike stemming, lemmatization considers the context and converts the word to its meaningful base form. For example, "better" might be lemmatized to "good".
# - **Removing Stop Words:** This involves eliminating common words that do not contribute much to the meaning of the text, such as "and", "the", "is", etc. Removing stop words helps in focusing on the important words in the text.

# %% [markdown]
# ####**N-grams**
# N-grams are contiguous sequences of 'n' items from a given text. They are used to capture context by analyzing combinations of words.
#
# - **Unigrams:** Sequences of one word (e.g., "text", "processing").
# - **Bigrams:** Sequences of two consecutive words (e.g., "text processing").
# - **Trigrams:** Sequences of three consecutive words (e.g., "text processing techniques").
#
# **Example of Applying Text Processing Techniques**
# - **Consider the sentence:** "The quick brown fox jumps over the lazy dog."
#
# **Word Tokenization:**
# ["The", "quick", "brown", "fox", "jumps", "over", "the", "lazy", "dog", "."]
#
# **Normalization:**
# - **Lowercasing:** ["the", "quick", "brown", "fox", "jumps", "over", "the", "lazy", "dog", "."]
# - **Removing Stop Words:** ["quick", "brown", "fox", "jumps", "lazy", "dog", "."]
# (Assuming stemming or lemmatization might not change these specific words significantly in this context)
# N-grams:
#
# - **Bigrams:** ["quick brown", "brown fox", "fox jumps", "jumps over", "over lazy", "lazy dog"]
# - **Trigrams:** ["quick brown fox", "brown fox jumps", "fox jumps over", "jumps over lazy", "over lazy dog"]
#
#
# **Applications of Text Processing Techniques**
# - **Search Engines:** Tokenization and normalization help in matching user queries with relevant documents.
# - **Text Classification:** Stop words removal and normalization improve the performance of text classifiers.
# - **Sentiment Analysis:** Lemmatization helps in understanding the sentiment by analyzing the root form of words, N-grams help in understanding the context for better translation accuracy.

# %% [markdown]
# # **Text Representation**

# %% [markdown]
# **Bag of Words (BoW)**
# - The Bag of Words model represents text as a collection of word counts, disregarding grammar and word order but keeping multiplicity.
#
# - **How It Works:** Each document is represented as a vector where each dimension corresponds to a unique word in the corpus. The value in each dimension is the count of the word's occurrences in the document.
#
# **Limitations:**
# - **Ignores Word Order:** BoW treats text as a set of words without considering their order.
# - **Ignores Context:** BoW does not capture semantic relationships between words.
# TF-IDF (Term Frequency-Inverse Document Frequency)
# TF-IDF is a statistical measure used to evaluate how important a word is to a document in a collection or corpus.
#
# - **Term Frequency (TF):** Measures the frequency of a term in a document. It’s calculated as the number of times a term appears in a document divided by the total number of terms in that document.

# %% [markdown]
# - **Inverse Document Frequency (IDF):** Measures the importance of a term across all documents. It’s calculated as the logarithm of the total number of documents divided by the number of documents containing the term.
#
#
# **TF-IDF Score:** The TF-IDF score is the product of TF and IDF.
# **TF-IDF = TF * IDF**

# %% [markdown]
# ####**Word Embeddings**
# - Word embeddings are dense vector representations of words that capture their meanings, semantic relationships, and syntactic properties.
#
# - **Word2Vec:** Generates word embeddings using two types of models:
# - **Skip-gram:** Predicts the context words given a target word.
# - **Continuous Bag of Words (CBOW):** Predicts the target word given the context words.
# - **GloVe (Global Vectors for Word Representation):** Uses a co-occurrence matrix factorization approach to generate word embeddings. It considers the global word-word co-occurrence statistics from a corpus.
# - **FastText:** Enhances Word2Vec by considering subword information. This means it breaks words into character n-grams and represents each word as the sum of its n-gram vectors, which helps in better handling of out-of-vocabulary words and capturing the internal structure of words.

# %% [markdown]
# Example of Applying Text Representation Techniques
#
# **Consider the following three sentences:**
#
# - "The cat sits on the mat."
# - "The dog sits on the mat."
# - "The cat lies on the rug."
#
# **Bag of Words Representation**
#
# - **Vocabulary:** ["The", "cat", "sits", "on", "the", "mat", "dog", "lies", "rug"]
# - **Sentence 1 Vector:** [1, 1, 1, 1, 1, 1, 0, 0, 0]
# - **Sentence 2 Vector:** [1, 0, 1, 1, 1, 1, 1, 0, 0]
# - **Sentence 3 Vector:** [1, 1, 0, 1, 1, 0, 0, 1, 1]
#
# **TF-IDF Representation**
# - **TF Calculation:** For each term in each document, calculate the term frequency.
# - **IDF Calculation:** Calculate the inverse document frequency for each term across all documents.
# - **TF-IDF Score:** Multiply the TF by IDF for each term in each document.
#
# **Word Embeddings (e.g., using Word2Vec)**
# - **Training:** Train a Word2Vec model on a large corpus to learn vector representations for words.
# - **Vector Representation:** Each word in the vocabulary is represented as a dense vector. For instance, "cat" might be represented as a vector [0.23, -0.15, 0.34, ...].
#
# **Applications of Text Representation Techniques**
# - **Document Similarity:** Using TF-IDF or word embeddings to compare the similarity between documents.
# - **Text Classification:** Representing text using BoW, TF-IDF, or embeddings for training classifiers.
# - **Information Retrieval:** Enhancing search engines by indexing documents with TF-IDF scores or word embeddings.
# -  **Sentiment Analysis:** Utilizing word embeddings to capture the sentiment expressed in text.

# %% [markdown]
# # **Deep Learning Models for NLP**

# %% [markdown]
# ####**Recurrent Neural Networks (RNNs)**
# - RNNs are designed for sequential data, making them suitable for tasks where the order of inputs matters, such as time series analysis and language modeling.
#
# **Key Features:**
# - **Sequential Processing:** RNNs process inputs in sequence, maintaining a hidden state that captures information about previous elements in the sequence.
# - **Capturing Dependencies:** They can capture dependencies over time but struggle with long-term dependencies due to issues like the vanishing gradient problem.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN

# Create an RNN model
model = Sequential()
model.add(SimpleRNN(50, input_shape=(10, 1)))  # RNN with 50 units, input shape (timesteps, features)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
# ...
# Total params: 2600 (10.16 KB)
# Trainable params: 2600 (10.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####**Long Short-Term Memory (LSTM)**
# - LSTMs are a type of RNN designed to overcome the vanishing gradient problem, making them capable of learning long-term dependencies.
#
# **Key Components:**
# - **Forget Gate:** Decides what information to discard from the cell state.
# - **Input Gate:** Decides what new information to store in the cell state.
# - **Output Gate:** Decides what part of the cell state to output.
# - **Advantages:** LSTMs can remember information for long periods and are effective in tasks like language translation and speech recognition.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM

# Create an LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(10, 1)))  # LSTM with 50 units, input shape (timesteps, features)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 50)                10400
#
# ...
# Total params: 10400 (40.62 KB)
# Trainable params: 10400 (40.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####**Gated Recurrent Unit (GRU)**
# - GRUs are a simplified version of LSTMs, designed to achieve similar performance with fewer parameters.
#
# **Key Components:**
# - **Reset Gate:** Determines how much of the past information to forget.
# - **Update Gate:** Determines how much of the new information to update to the current hidden state.
# - **Advantages:** GRUs are computationally more efficient than LSTMs while maintaining similar effectiveness for many tasks.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU

# Create a GRU model
model = Sequential()
model.add(GRU(50, input_shape=(10, 1)))  # GRU with 50 units, input shape (timesteps, features)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  gru (GRU)                   (None, 50)                7950
#
# ...
# Total params: 7950 (31.05 KB)
# Trainable params: 7950 (31.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####**Convolutional Neural Networks (CNNs)**
# - Convolutional Neural Networks (CNNs) for Text
# Although CNNs are typically used in image processing, they can also be applied to text for tasks like sentence classification by capturing local features.
#
# **Key Features:**
# - **Local Feature Extraction:** Convolutions capture local patterns in the text, such as n-grams.
# - **Pooling Layers:** Reduce dimensionality while retaining important information.
# - **Applications:** CNNs are effective for text classification, sentiment analysis, and other tasks where local patterns are informative.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense

# Create a CNN model for text classification
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=128, input_length=100))  # Embedding layer
model.add(Conv1D(128, 5, activation='relu'))  # Convolutional layer
model.add(GlobalMaxPooling1D())  # Global max pooling layer
model.add(Dense(10, activation='softmax'))  # Output layer

model.summary()

# %% [markdown]
# ####**Attention Mechanisms**
# - Attention mechanisms allow models to focus on relevant parts of the input sequence, improving performance in tasks like machine translation and summarization.
#
# **Key Features:**
# - **Weighted Sum:** Calculates a weighted sum of the input elements, where the weights are learned.
# - **Focus on Relevance:** Helps the model to focus on the most relevant parts of the input for a given task.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Input, Dense
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt

class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight', shape=(input_shape[-1], input_shape[-1]), initializer='random_normal', trainable=True)
        self.b = self.add_weight(name='attention_bias', shape=(input_shape[-1],), initializer='zeros', trainable=True)
        super(Attention, self).build(input_shape)

    def call(self, inputs):
        e = tf.nn.tanh(tf.tensordot(inputs, self.W, axes=1) + self.b)
        a = tf.nn.softmax(e, axis=1)
        output = inputs * a
        return tf.reduce_sum(output, axis=1), a

# Create a simple model with attention
input_seq = Input(shape=(10, 64))
attention_layer, attention_weights = Attention()(input_seq)
output = Dense(1, activation='sigmoid')(attention_layer)
model = Model(inputs=input_seq, outputs=output)
model.summary()

# Create a model to get the attention weights
attention_model = Model(inputs=input_seq, outputs=attention_weights)

# Dummy data to visualize attention weights
dummy_data = np.random.random((1, 10, 64))

# Ensure predict function is traced only once
@tf.function
def get_attention_weights(input_data):
    return attention_model(input_data)

# Get the attention weights
attention_weights = get_attention_weights(dummy_data)

# Plot attention weights
plt.matshow(attention_weights.numpy().squeeze())
plt.colorbar()
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 10, 64)]          0
#
#  attention (Attention)       ((None, 64),              4160
#                               (None, 10, 64))
#
#  dense (Dense)               (None, 1)                 65
#
# ...
# Total params: 4225 (16.50 KB)
# Trainable params: 4225 (16.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####**Transformer Architecture**
# - The Transformer model, based entirely on attention mechanisms, is designed to handle dependencies regardless of their distance in the input sequence.
#
# **Key Components:**
# - **Multi-Head Attention:** Allows the model to focus on different parts of the sequence simultaneously.
# - **Positional Encoding:** Adds information about the position of words in the sequence, since the model itself has no inherent sense of order.
# - **Feed-Forward Neural Networks:** Applied to each position separately and identically.
# - **Layer Normalization:** Normalizes the output of the previous layer to stabilize and accelerate training.
# - **Advantages:** Transformers handle long-range dependencies efficiently and have become the foundation for many state-of-the-art NLP models.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Embedding, MultiHeadAttention, LayerNormalization, Dropout
from tensorflow.keras.models import Model

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = LayerNormalization(epsilon=1e-6)(res)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    x = Dense(inputs.shape[-1])(x)
    return x + res

# Create a simple Transformer model
input_seq = Input(shape=(None, 128))
x = transformer_encoder(input_seq, head_size=128, num_heads=8, ff_dim=256, dropout=0.1)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=input_seq, outputs=output)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, None, 128)]          0         []
#
#  layer_normalization (Layer  (None, None, 128)            256       ['input_3[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, None, 128)            527488    ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout (Dropout)           (None, None, 128)            0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, None, 128)            0         ['dropout[0][0]',
#  Lambda)                                                             'input_3[0][0]']
#
#  layer_normalization_1 (Lay  (None, None, 128)            256       ['tf.__operators__.add[0][0]']
#  erNormalization)
#
# ...

# %% [markdown]
# ####**BERT (Bidirectional Encoder Representations from Transformers)**
# BERT is a pre-trained Transformer model designed to understand the context of a word based on its surroundings (bidirectional context).
#
# - **Pre-training:** Trained on large corpora using tasks like Masked Language Modeling (MLM) and Next Sentence Prediction (NSP).
# - **Fine-tuning:** Can be fine-tuned for specific NLP tasks such as question answering, sentiment analysis, and named entity recognition.
# - **Advantages:** BERT achieves high performance by capturing deep bidirectional relationships in text.

# %%
from transformers import BertModel, BertTokenizer
import torch

# Load pre-trained BERT model and tokenizer
model = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Encode a sample text
inputs = tokenizer("Hello, my dog is cute", return_tensors='pt')
outputs = model(**inputs)

# Model summary
print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
# ...

# %% [markdown]
# ####**GPT (Generative Pre-trained Transformer)**
#
#  GPT focuses on generating coherent text by predicting the next word in a sequence, trained using unidirectional context.
#
# - **Pre-training:** Trained on a large corpus using a language modeling objective.
# - **Fine-tuning:** Can be fine-tuned for various NLP tasks like text generation, translation, and summarization.
# - **Advantages:** GPT excels in generating human-like text and has been used for tasks such as story generation and dialogue systems.

# %%
from transformers import GPT2Model, GPT2Tokenizer
import torch

# Load pre-trained GPT-2 model and tokenizer
model = GPT2Model.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Encode a sample text
inputs = tokenizer("Once upon a time", return_tensors='pt')
outputs = model(**inputs)

# Model summary
print(model)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# GPT2Model(
#   (wte): Embedding(50257, 768)
#   (wpe): Embedding(1024, 768)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-11): 12 x GPT2Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
# ...

# %% [markdown]
# ####**Applications of Deep Learning Models in NLP**
# - **Machine Translation:** Using models like RNNs, LSTMs, GRUs, and Transformers to translate text between languages.
# - **Text Classification:** Utilizing CNNs, RNNs, and Transformers to categorize text into predefined labels.
# - **Question Answering:** Applying models like BERT to understand and answer questions based on context.
# - **Text Generation:** Leveraging GPT to create coherent and contextually relevant text, such as in chatbots and content creation.

# %% [markdown]
# #**Applications of NLP**

# %% [markdown]
# ####**Sentiment Analysis**
# - Sentiment analysis involves determining the sentiment expressed in a text, such as positive, negative, or neutral.

# %%
from transformers import pipeline

# Load a sentiment-analysis pipeline
nlp = pipeline("sentiment-analysis")

# Analyze sentiment of a sample text
result = nlp("I love this product! It's amazing.")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998866319656372}]

# %% [markdown]
# ####**Machine Translation**
# - Machine translation involves translating text from one language to another.

# %%
from transformers import MarianMTModel, MarianTokenizer

# Load pre-trained Marian model and tokenizer
model_name = 'Helsinki-NLP/opus-mt-en-fr'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Translate a sample text
text = "Hello, how are you?"
translated = model.generate(**tokenizer(text, return_tensors="pt", padding=True))
print([tokenizer.decode(t, skip_special_tokens=True) for t in translated])
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# ['Bonjour, comment allez-vous?']

# %% [markdown]
# ####**Named Entity Recognition (NER)**
# NER involves identifying and classifying entities in text, such as names, dates, and locations.

# %%
from transformers import pipeline

# Load a NER pipeline
nlp = pipeline("ner")

# Perform NER on a sample text
text = "Barack Obama was born on August 4, 1961 in Honolulu, Hawaii."
result = nlp(text)
print(result)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# ####**Text Summarization**
# - Text summarization involves creating concise summaries of longer texts.
#
# #####**Extractive Summarization**
# - Selecting key sentences from the original text.

# %%
from transformers import pipeline

# Load an extractive summarization pipeline
summarizer = pipeline("summarization")

# Summarize a sample text
text = """The quick brown fox jumps over the lazy dog. The quick brown fox is known for its agility.
The lazy dog, on the other hand, prefers to lie around and take naps all day."""
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Your max_length is set to 50, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# [{'summary_text': ' The quick brown fox is known for its agility . The lazy dog, on the other hand, prefers to lie around and take naps all day .'}]

# %% [markdown]
# #####**Abstractive Summarization**
# Generating new sentences to capture the essence of the text.

# %%
from transformers import pipeline

# Load an abstractive summarization pipeline (same pipeline as extractive for this example)
summarizer = pipeline("summarization")

# Summarize a sample text
text = """The quick brown fox jumps over the lazy dog. The quick brown fox is known for its agility.
The lazy dog, on the other hand, prefers to lie around and take naps all day."""
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Your max_length is set to 50, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# [{'summary_text': ' The quick brown fox is known for its agility . The lazy dog, on the other hand, prefers to lie around and take naps all day .'}]

# %% [markdown]
# ####**Question Answering**
# Building systems that can answer questions based on a given context.

# %%
from transformers import pipeline

# Load a question-answering pipeline
qa_pipeline = pipeline("question-answering")

# Define context and question
context = "The Eiffel Tower is a wrought-iron lattice tower on the Champ de Mars in Paris, France."
question = "Where is the Eiffel Tower located?"

# Get the answer
result = qa_pipeline(question=question, context=context)
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# {'score': 0.3227175176143646, 'start': 56, 'end': 86, 'answer': 'Champ de Mars in Paris, France'}

# %% [markdown]
# # **NLP Pipelines and Frameworks**

# %% [markdown]
# ##**NLP Libraries**
# 1. NLTK (Natural Language Toolkit)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# Sample text
text = "Natural Language Processing is fascinating. Let's learn NLTK!"

# Sentence Tokenization
sentences = sent_tokenize(text)
print("Sentences:", sentences)

# Word Tokenization
words = word_tokenize(text)
print("Words:", words)

# Stop Words Removal
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print("Filtered Words:", filtered_words)
# Out:
# Sentences: ['Natural Language Processing is fascinating.', "Let's learn NLTK!"]
# Words: ['Natural', 'Language', 'Processing', 'is', 'fascinating', '.', 'Let', "'s", 'learn', 'NLTK', '!']
# Filtered Words: ['Natural', 'Language', 'Processing', 'fascinating', '.', 'Let', "'s", 'learn', 'NLTK', '!']

# %% [markdown]
# ####**SpaCy**

# %%
import spacy

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# Sample text
text = "Apple is looking at buying U.K. startup for $1 billion."

# Process the text
doc = nlp(text)

# Tokenization
tokens = [token.text for token in doc]
print(tokens)

# Named Entity Recognition (NER)
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)
# Out:
# ['Apple', 'is', 'looking', 'at', 'buying', 'U.K.', 'startup', 'for', '$', '1', 'billion', '.']
# [('Apple', 'ORG'), ('U.K.', 'GPE'), ('$1 billion', 'MONEY')]

# %% [markdown]
# ####**Stanford NLP**

# %%
pip install stanza
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 9.0 MB/s eta 0:00:00
# ...

# %%
import stanza

# Download the English models for the neural pipeline
stanza.download('en')

# Initialize the pipeline
nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,depparse')

# Sample text
text = "Stanford University is located in California."

# Process the text
doc = nlp(text)

# Print out tokens and their POS tags
for sentence in doc.sentences:
    for word in sentence.words:
        print(f'word: {word.text}\tPOS: {word.pos}')
# Out:
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# ...
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# ...

# %% [markdown]
# ##**Deep Learning Frameworks**

# %% [markdown]
# ####**TensorFlow and Keras**

# %% [markdown]
# TensorFlow and its high-level API Keras provide tools to build and train deep learning models.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Sample data
vocab_size = 10000
embedding_dim = 16
max_length = 100

# Create a simple LSTM model
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_length),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 16)           160000
#
#  lstm (LSTM)                 (None, 64)                20736
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 180801 (706.25 KB)
# Trainable params: 180801 (706.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ####**PyTorch**
# PyTorch is a deep learning framework that provides flexibility and speed for building and training models.

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Sample LSTM Model in PyTorch
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embedded = self.embedding(x)
        lstm_out, _ = self.lstm(embedded)
        out = self.fc(lstm_out[:, -1, :])
        return self.sigmoid(out)

# Model parameters
vocab_size = 10000
embedding_dim = 16
hidden_dim = 64
output_dim = 1

# Initialize model, loss function, and optimizer
model = LSTMClassifier(vocab_size, embedding_dim, hidden_dim, output_dim)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Model summary
print(model)
# Out:
# LSTMClassifier(
#   (embedding): Embedding(10000, 16)
#   (lstm): LSTM(16, 64, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
